# %%
import re
import random

import pandas as pd

# %%
# 80 sustantivos
sustantivos = [
    'abuelo', 'actor', 'agujero', 'albañil', 'alce', 'animal', 'árbol', 'arquitecto', 'auto', 'avión',
    'barco', 'barril', 'bosque', 'burro', 'caballo', 'cable', 'camello', 'camino', 'caracol', 'carro',
    'cielo', 'coche', 'cocodrilo', 'conejo', 'desierto', 'diamante', 'dragón',
    'edificio', 'elefante', 'escritor', 'espejo', 'estrecho', 'fuego', 'gallo', 'gato', 'gorila',
    'grifo', 'héroe', 'hijo', 'hombre', 'hospital', 'indio', 'jardín', 'jinete', 
    'lagarto', 'lago', 'lápiz', 'león', 'libro', 'lobo', 'lugar', 'martillo', 'mono',
    'motor', 'mueble', 'mundo', 'naranjo', 'negocio', 'niño', 'oso', 'pájaro', 'papel',
    'payaso', 'pez', 'plátano', 'pozo', 'puente', 'río', 'reloj', 'rey',
    'robot', 'sol', 'sombrero', 'tambor', 'tigre', 'torre', 'tren', 'viento', 'zapato', 'zorro'
    ]


# 20 sustantivos jabberwockie
jabberwockie_nouns = [
    'blicket', 'flajuf', 'flakle', 'jufmoq', 'jufzyl', 'kleqor', 'klesyl', 'moqkle', 'moqzyl', 'nerpif',
    'nerqor', 'pifner', 'piftrun', 'qorjuf', 'qortrun', 'trunfla', 'trunpif', 'vexfla', 'vexner', 'zylner'
    ]


# 80 verbos intransitivos
intransitive_verbs = [
    'acuerda', 'aguanta', 'ama', 'amanece', 'anochece', 'aparece', 'aplaude', 'avanza', 'baja', 'bosteza',  
    'brinca', 'cae', 'calla', 'cambia', 'camina', 'canta', 'carraspea', 'celebra', 'contempla', 'converge',  
    'corre', 'crece', 'deambula', 'delira', 'descansa', 'desaparece', 'desliza', 'divaga', 'duerme',  
    'emerge', 'entra', 'escala', 'explora', 'fallece', 'florece', 'flota', 'fluye', 'fracasa',  
    'gira', 'grita', 'jadea', 'late', 'llega', 'llora', 'marcha', 'mejora', 'muere', 'nace', 'nada',  
    'oscurece', 'parte', 'parpadea', 'pasea', 'persigue', 'piensa', 'progresa', 'reflexiona', 'reposa',  
    'resbala', 'resiste', 'respira', 'retrocede', 'retorna', 'ríe', 'sale', 'salta', 'soporta',  
    'sube', 'sueña', 'suspende', 'suspira', 'surge', 'tiembla', 'tose', 'transcurre', 'tropieza',  
    'vaga', 'viaja', 'vibra', 'vive'
]

# 20 verbos jabberwockie
jabberwockie_verbs = jabberwockie_verbs = [
    'bliscea', 'brilca', 'brunza', 'dernea', 'drifla', 'flumea', 'frochea', 'glaquea', 'gralpa', 'jurne',
    'larquea', 'pluquea', 'pruspa', 'quesea', 'tapla', 'tintera', 'trejea', 'zopla', 'zumnea', 'zurna'
]

# 80 adjetivos
adjs = [
    'alegre', 'alto', 'amargo', 'amplio', 'amarillo', 'apagado', 'asombroso', 'áspero', 'azul',  
    'bajo', 'blando', 'brillante', 'caliente', 'cansado', 'claro', 'complejo', 'débil', 'delgado',  
    'difícil', 'dulce', 'duro', 'elegante', 'enojado', 'feliz', 'fino', 'fácil', 'frío',  
    'fresco', 'fuerte', 'gordo', 'grande', 'grueso', 'hermoso', 'honesto', 'humilde', 'ingenioso',  
    'inteligente', 'joven', 'lento', 'leve', 'ligero', 'limpio', 'listo', 'luminoso', 'manso', 
    'moderno', 'mojado', 'negro', 'noble', 'nuevo', 'opaco', 'optimista', 'oscuro', 'paciente',  
    'pesado', 'picante', 'pobre', 'poderoso', 'podrido', 'puntual', 'rápido', 'recto', 'rojo',  
    'rugoso', 'sabroso', 'salado', 'seco', 'seguro', 'sereno', 'simple', 'sincero', 'sucio', 'suave',  
    'tímido', 'torcido', 'transparente', 'triste', 'valiente', 'verde', 'viejo'
]


# 20 adjetivos jabberwockie
jabberwockie_adjs = [
    'brispado', 'claribundo', 'dormínico', 'florido', 'flexivo', 'frenzático', 'gloridio', 'gornoso',
    'lirboso', 'lumífero', 'morflino', 'palgado', 'serpálico', 'sintálico', 'talístico', 'tornadizo',
    'tripante', 'vistreante', 'zongoso', 'zurdulante'
]

# random.shuffle(nouns)
# random.shuffle(jabberwockie_nouns)
# random.shuffle(intransitive_verbs)
# random.shuffle(jabberwockie_verbs)
# random.shuffle(adjs)
# random.shuffle(jabberwockie_adjs)


TAMANO = 5
file_name = 'implicacion_jabberwockie_5.csv'

# %%
# Parejas en relación de implicación 1,0

parejas = [
['todo', 'noun', 'verb1', ',', 'algún', 'noun', 'verb1'],
['todo', 'noun', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'verb1', 'y', 'verb2'],
['todo', 'noun', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'verb1', 'o', 'verb2'],

#['todo', 'noun', 'adj', 'verb1', ',', 'algún', 'noun', 'adj', 'verb1'],
#['todo', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'adj', 'verb1', 'y', 'verb2'],
#['todo', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'adj', 'verb1', 'o', 'verb2'],

['ningún', 'noun', 'verb1', ',', 'algún', 'noun', 'no', 'verb1'],
['ningún', 'noun', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'no', 'verb1', 'o', 'no', 'verb2'],
['ningún', 'noun', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'no', 'verb1', 'y', 'no', 'verb2'],

#['ningún', 'noun', 'adj', 'verb1', ',', 'algún', 'noun', 'adj', 'no', 'verb1'],
#['ningún', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'adj', 'no', 'verb1', 'o', 'no', 'verb2'],
#['ningún', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'adj', 'no', 'verb1', 'y', 'no', 'verb2'],

['todo', 'noun', 'verb1', ',', 'todo', 'noun', 'adj', 'verb1'],
['todo', 'noun', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'adj', 'verb1', 'y', 'verb2'],
['todo', 'noun', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'adj', 'verb1', 'o', 'verb2'],

['algún', 'noun', 'adj', 'verb1', ',', 'algún', 'noun', 'verb1'],
['algún', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'verb1', 'y', 'verb2'],
['algún', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'verb1', 'o', 'verb2']
]

# %%
def crear_instancias_jabberwockie(par,modo,etiqueta):
    with open(file_name, modo, encoding = 'utf-8') as f:
        for noun in jabberwockie_nouns[:TAMANO]:
            for verb1 in jabberwockie_verbs[:TAMANO]:
                if 'adj' in par:
                    for adj in jabberwockie_adjs[:TAMANO]:
                        if 'verb2' in par:
                            for verb2 in jabberwockie_verbs[:TAMANO]:
                                if verb1 == verb2:
                                    continue
                                oraciones = ' '.join(par)
                                oraciones = re.sub('noun',noun,oraciones)
                                oraciones = re.sub('adj',adj,oraciones)
                                oraciones = re.sub('verb1',verb1,oraciones)
                                oraciones = re.sub('verb2',verb2,oraciones)
                                datapoint = oraciones + etiqueta + '\n'
                                f.write(''.join(datapoint))
                        else:
                            oraciones = ' '.join(par)
                            oraciones = re.sub('noun',noun,oraciones)
                            oraciones = re.sub('adj',adj,oraciones)
                            oraciones = re.sub('verb1',verb1,oraciones)
                            datapoint = oraciones + etiqueta + '\n'
                            f.write(''.join(datapoint))
                else:
                    if 'verb2' in par:
                        for verb2 in jabberwockie_verbs[:TAMANO]:
                                if verb1 == verb2:
                                    continue
                                oraciones = ' '.join(par)
                                oraciones = re.sub('noun',noun,oraciones)
                                oraciones = re.sub('verb1',verb1,oraciones)
                                oraciones = re.sub('verb2',verb2,oraciones)
                                datapoint = oraciones + etiqueta + '\n'
                                f.write(''.join(datapoint))
                    else:
                        oraciones = ' '.join(par)
                        oraciones = re.sub('noun',noun,oraciones)
                        oraciones = re.sub('verb1',verb1,oraciones)
                        datapoint = oraciones + etiqueta + '\n'
                        f.write(''.join(datapoint))

# %%
inicial = True
for par in parejas:
    if inicial:
        modo = 'w'
        inicial = False
    else:
        modo = 'a'
    crear_instancias_jabberwockie(par,modo,', 1, 0')

# %%
# Parejas equivalentes 1,1 

parejas_equivalentes = [
['no', 'todo', 'noun', 'adj', 'verb1', ',', 'algún', 'noun', 'adj', 'no', 'verb1'],
['no', 'todo', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'adj', 'no', 'verb1', 'o', 'no', 'verb2'],
['no', 'todo', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'adj', 'no', 'verb1', 'y', 'no', 'verb2'],

['no', 'todo', 'noun', 'verb1', ',', 'algún', 'noun', 'no', 'verb1'],
['no', 'todo', 'noun', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'no', 'verb1', 'o', 'no', 'verb2'],
['no', 'todo', 'noun', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'no', 'verb1', 'y', 'no', 'verb2'],

['todo', 'noun', 'adj', 'verb1', ',', 'no', 'algún', 'noun', 'adj', 'no', 'verb1'],
['todo', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'no', 'algún', 'noun', 'adj', 'no', 'verb1', 'o', 'no', 'verb2'],
['todo', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'no', 'algún', 'noun', 'adj', 'no', 'verb1', 'y', 'no', 'verb2'],

['no', 'algún', 'noun', 'no', 'verb1', ',', 'todo', 'noun', 'verb1'],
['no', 'algún', 'noun', 'no', 'verb1', 'o', 'no', 'verb2', ',', 'todo', 'noun', 'verb1', 'y', 'verb2'],
['no', 'algún', 'noun', 'no', 'verb1', 'y', 'no', 'verb2', ',', 'todo', 'noun', 'verb1', 'o', 'verb2'],

['no', 'algún', 'noun', 'adj', 'verb1', ',', 'ningún', 'noun', 'adj', 'verb1'],
['no', 'algún', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'ningún', 'noun', 'adj', 'verb1', 'y', 'verb2'],
['no', 'algún', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'ningún', 'noun', 'adj', 'verb1', 'o', 'verb2'],

['no', 'algún', 'noun', 'verb1', ',', 'ningún', 'noun', 'verb1'],
['no', 'algún', 'noun', 'verb1', 'y', 'verb2', ',', 'ningún', 'noun', 'verb1', 'y', 'verb2'],
['no', 'algún', 'noun', 'verb1', 'o', 'verb2', ',', 'ningún', 'noun', 'verb1', 'o', 'verb2'],

['no', 'algún', 'noun', 'adj', 'verb1', ',', 'todo', 'noun', 'adj', 'no', 'verb1'],
['no', 'algún', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'adj', 'no', 'verb1', 'o', 'no', 'verb2'],
['no', 'algún', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'adj', 'no', 'verb1', 'y', 'no', 'verb2'],

['no', 'algún', 'noun', 'verb1', ',', 'todo', 'noun', 'no', 'verb1'],
['no', 'algún', 'noun', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'no', 'verb1', 'o', 'no', 'verb2'],
['no', 'algún', 'noun', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'no', 'verb1', 'y', 'no', 'verb2'],

['todo', 'noun', 'adj', 'no', 'verb1', ',', 'ningún', 'noun', 'adj', 'verb1'],
['todo', 'noun', 'adj', 'no', 'verb1', 'o', 'no', 'verb2', ',', 'ningún', 'noun', 'adj', 'verb1', 'y', 'verb2'],
['todo', 'noun', 'adj', 'no', 'verb1', 'y', 'no', 'verb2', ',', 'ningún', 'noun', 'adj', 'verb1', 'o', 'verb2'],

['todo', 'noun', 'no', 'verb1', ',', 'ningún', 'noun', 'verb1'],
['todo', 'noun', 'no', 'verb1', 'o', 'no', 'verb2', ',', 'ningún', 'noun', 'verb1', 'y', 'verb2'],
['todo', 'noun', 'no', 'verb1', 'y', 'no', 'verb2', ',', 'ningún', 'noun', 'verb1', 'o', 'verb2']
]

# %%
for par in parejas_equivalentes:
    crear_instancias_jabberwockie(par,'a',', 1, 1')

# %%
# Parejas negativas positivas 0,1

parejas_negativas_positivas =[
['algún', 'noun', 'verb1', ',', 'todo', 'noun', 'verb1'],
['algún', 'noun', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'verb1', 'y', 'verb2'],
['algún', 'noun', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'verb1', 'o', 'verb2'],

#['algún', 'noun', 'adj', 'verb1', ',', 'todo', 'noun', 'adj', 'verb1'],
#['algún', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'adj', 'verb1', 'y', 'verb2'],
#['algún', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'adj', 'verb1', 'o', 'verb2'],

['todo', 'noun', 'adj', 'verb1', ',', 'todo', 'noun', 'verb1'],
['todo', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'verb1', 'y', 'verb2'],
['todo', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'verb1', 'o', 'verb2'],

['algún', 'noun', 'verb1', ',', 'algún', 'noun', 'adj', 'verb1'],
['algún', 'noun', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'adj', 'verb1', 'y', 'verb2'],
['algún', 'noun', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'adj', 'verb1', 'o', 'verb2'],

['algún', 'noun', 'no', 'verb1', ',', 'ningún', 'noun', 'verb1'],
['algún', 'noun', 'no', 'verb1', 'o', 'no', 'verb2', ',', 'ningún', 'noun', 'verb1', 'y', 'verb2'],
['algún', 'noun', 'no', 'verb1', 'y', 'no', 'verb2', ',', 'ningún', 'noun', 'verb1', 'o', 'verb2'],

#['algún', 'noun', 'adj', 'no', 'verb1', ',', 'ningún', 'noun', 'adj', 'verb1'],
#['algún', 'noun', 'adj', 'no', 'verb1', 'o', 'no', 'verb2', ',', 'ningún', 'noun', 'adj', 'verb1', 'y', 'verb2'],
#['algún', 'noun', 'adj', 'no', 'verb1', 'y', 'no', 'verb2', ',', 'ningún', 'noun', 'adj', 'verb1', 'o', 'verb2'],
]

# %%
for par in parejas_negativas_positivas:
    crear_instancias_jabberwockie(par,'a',', 0, 1')

# %%
# Parejas negativas negativas 0,0

parejas_negativas_negativas = [
['todo', 'noun', 'verb1', ',', 'algún', 'noun', 'no', 'verb1'],
['todo', 'noun', 'adj', 'verb1', ',', 'algún', 'noun', 'adj', 'no', 'verb1'],
['todo', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'adj', 'no', 'verb1', 'o', 'no', 'verb2'],
['todo', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'adj', 'no', 'verb1', 'y', 'no', 'verb2'],
['todo', 'noun', 'verb1', 'y', 'verb2', ',', 'algún', 'noun', 'no', 'verb1', 'o', 'no', 'verb2'],
['todo', 'noun', 'verb1', 'o', 'verb2', ',', 'algún', 'noun', 'no', 'verb1', 'y', 'no', 'verb2'],

['no', 'todo', 'noun', 'verb1', ',', 'todo', 'noun', 'verb1'],
['no', 'todo', 'noun', 'adj', 'verb1', ',', 'todo', 'noun', 'adj', 'verb1'],
['no', 'todo', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'adj', 'verb1', 'y', 'verb2'],
['no', 'todo', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'adj', 'verb1', 'o', 'verb2'],
['no', 'todo', 'noun', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'verb1', 'y', 'verb2'],
['no', 'todo', 'noun', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'verb1', 'o', 'verb2'],

['algún', 'noun', 'verb1', ',', 'ningún', 'noun', 'verb1'],
['algún', 'noun', 'adj', 'verb1', ',', 'ningún', 'noun', 'adj', 'verb1'],

['algún', 'noun', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'no', 'verb1', 'o', 'no', 'verb2'],
['algún', 'noun', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'no', 'verb1', 'y', 'no', 'verb2'],
['algún', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'adj', 'no', 'verb1', 'o', 'no', 'verb2'],
['algún', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'adj', 'no', 'verb1', 'y', 'no', 'verb2'],

['algún', 'noun', 'verb1', ',', 'todo', 'noun', 'no', 'verb1'],
['algún', 'noun', 'adj', 'verb1', ',', 'todo', 'noun', 'adj', 'no', 'verb1'],
['algún', 'noun', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'no', 'verb1', 'o', 'no', 'verb2'],
['algún', 'noun', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'no', 'verb1', 'y', 'no', 'verb2'],
['algún', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'adj', 'no', 'verb1', 'o', 'no', 'verb2'],
['algún', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'adj', 'no', 'verb1', 'y', 'no', 'verb2'],

['algún', 'noun', 'adj', 'verb1', ',', 'todo', 'noun', 'adj', 'verb1'],
['algún', 'noun', 'adj', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'adj', 'verb1', 'y', 'verb2'],
['algún', 'noun', 'adj', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'adj', 'verb1', 'o', 'verb2'],
['algún', 'noun', 'verb1', ',', 'todo', 'noun', 'verb1'],
['algún', 'noun', 'verb1', 'y', 'verb2', ',', 'todo', 'noun', 'verb1', 'y', 'verb2'],
['algún', 'noun', 'verb1', 'o', 'verb2', ',', 'todo', 'noun', 'verb1', 'o', 'verb2']
]

# %%
for par in parejas_negativas_negativas:
    crear_instancias_jabberwockie(par,'a',', 0, 0')

# %%
df = pd.read_csv(file_name)

num_filas = len(df)+1
print(f"El tamaño del dataset creado es: {num_filas}")
# Out:
# El tamaño del dataset creado es: 18900
